# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
import mlxtend
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
from matplotlib import rc, font_manager
import matplotlib.font_manager as fm

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:/Windows/Fonts/malgun.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %% [markdown]
# ### csv 전처리

# %%
df=pd.read_csv('favorite_MOCK_DATA.csv')

# %%
df.set_index('member_idx', inplace=True)

# %%
df[0:1]
# Out:
#              여행지1    여행지2     여행지3    여행지4        여행지5       여행지6       여행지7  \
# member_idx
# 1           Dębno  Alicia  Buzuluk  Trąbki  Sorochinsk  Checacupe  Werangere
#
#                  여행지8         여행지9                     여행지10
# member_idx
# 1           Espinillo  Wanlongshan  Vila Nova de Santo André

# %%
favorite=df['여행지1'].str.cat(df['여행지2'], sep=' ').str.cat(df['여행지3'], sep=' ').str.cat(df['여행지4'], sep=' ').str.cat(df['여행지5'], sep=' ').str.cat(df['여행지6'], sep=' ').str.cat(df['여행지7'], sep=' ').str.cat(df['여행지8'], sep=' ').str.cat(df['여행지9'], sep=' ').str.cat(df['여행지10'], sep=' ')
favorite[:3]
# 여행지 1~10을 하나의 String으로 묶기
# Out:
# member_idx
# 1    Dębno Alicia Buzuluk Trąbki Sorochinsk Checacu...
# 2    Warburton Bader Padre Paraíso Meiyao Takanabe ...
# 3    Ilhabela Jiangbei Valença do Piauí Guilmaro To...
# Name: 여행지1, dtype: object

# %%
list(favorite)
# Out:
# ['Dębno Alicia Buzuluk Trąbki Sorochinsk Checacupe Werangere Espinillo Wanlongshan Vila Nova de Santo André',
#  'Warburton Bader Padre Paraíso Meiyao Takanabe Cidolog Chengguan Datarsitu Hailin Rumenka',
#  'Ilhabela Jiangbei Valença do Piauí Guilmaro Topi Nakhon Chai Si Hamburg Maripa Tampa Zhongchao',
#  'Donskoy San Bautista Mino Bombarral Miao’ertan Sakai Åtvidaberg Përmet Ilongero Pailitas',
#  'Wangren Lyon Intipucá Cidahu Kaset Sombun Changling Lycksele Purwokerto Troyes Koungheul',
#  'Albina Hữu Lũng Aduo Prince Edward Idhnā Novhorodka Yisuhe Mbala Inhumas Zaytā Jammā‘īn',
#  'Lunao Longhua Solna Lodhrān Šentilj v Slov. Goricah Thị Trấn Cẩm Thủy Nubl Zherdevka Velyki Sorochyntsi Gugut',
#  'Verkh-Usugli Pamotan Fundong Luopioinen Datarnangka Malausma Kidul Penha Crossmolina Kokofata Besançon',
#  'Tsuruga Nossa Senhora da Glória Rassvet Chantepie Nossa Senhora da Glória Sanguansi Severka Sussex Siquanpu Ljutomer',
# ...

# %% [markdown]
# ### TF-IDF, 코사인 유사도

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

# %%
tfidf = TfidfVectorizer()

# %%
tfidf_matrix = tfidf.fit_transform(favorite)
