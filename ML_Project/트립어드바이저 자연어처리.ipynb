# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
from nltk import FreqDist
from wordcloud import WordCloud

# %%
from konlpy.tag import Okt

# %%
t=Okt()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import matplotlib.font_manager as fm

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:/Windows/Fonts/malgun.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
import nltk

# %%
str="세종대왕 동상"

# %%
f = open('reviews/txt/'+str+' 리뷰.txt','r', encoding='UTF-8')
review = f.read()
f.close()

# %%
review
# Out:
# "조선의 4대 왕 세종은 과학을 발전시키는 데에 큰 힘을 기울였으며, 특히 그가 창제한 한글 역시 과학성의 측면에서 매우 중요한 결과물이다. 2009년 광화문 앞의 세종로를 노상 시민광장으로 조성하면서 설치하였으며, 그 결과 기존의 이순신 장군의 입상을 뛰어넘는 새로운 광장의 상징물로 자리잡게 되었다. 동상은 단순히 세종대왕의 좌상으로만 구성되지 않으며, 주위로 그의 과학에 대한 관심이 만들어낸 발명들의 모형이 전시되면서 이미 이곳의 길 이름까지 그에게서 따온 것인만큼 그곳에까지 큰 의미를 부여하고 있다. 광화문과 이순신 동상의 가운데에 설치되어 문과의 조화 또한 잘 되어 있다는 점까지 있으며 야간에도 좋은 볼거리가 되는 곳이다.\n서울 광화문 광장에 웅장하게 앉아있는 세종대왕 동상을 보노라면이 시대를 사는 사람들에게 무언가 한 마다 할 것 같은 대왕이 모습이 보는 이를 숙연하게 합니다.\n광화문 여행시 사진찍으면 좋은 곳. 광화문 대로에 중간에 우뚝 서있어 찾기도 편하다. 외국인들이 세종대왕 동상 앞에서 사진을 많이 찍는다.\n한국인으로서 자부심을 느끼게 하는 한글을 발명한 세종대왕의 위엄있는 동상이 정말 멋있습니다. 조명까지 받으면 더하죠.\n우리말 우리글을 만든\n아마 지금 조사를 한다면 조선시대를 통틀어 가장 많이 알고 가장 훌륭한 임금으로 꼽히지 않을까?\n한글 하나만으로 이미 모든 까방권을 가지고 계신 분.\n광화문 광장에 왔다면 주변 여러 궁과 미술관 박물관을 들르기 전 사진 한 장 찍는것도 좋을 것 같다.\n서울의 상징 중의 하나\n조선의 위대한 군주이자 국민들이 존경하는 위인 일순위로 유력한 분\n집현전 학자들과 한글을 같이 만들었다고 알려져 있었으나\n사실 집현전 학자들은 한글을 반대했고 군주 스스로 한글을 창제한 것이\n밝혀져 나를 놀라게 했던 위대한 인물.\n세종대왕을 좋은 사람이라 칭송하지만 사실은 나쁜놈이다..\n조선의 노비제도를 만든게 세종대왕이기 때문이지\n좋은 역사만 보려하지 말고 나쁜 역사도 보아야 한다.\n한글도 이놈이 만든게 아니고 학자들이 만들었고 또 한자를 위해서 만든게 한글이라고 한다\n어렸을때 위인전을 읽을때도 대단하다는 생각이 들었는데, 크면 클수록 정말 세종대왕님은 정말 대단하다를 넘어서 천재가 아닐까 싶네요. 어릴때부터 책을 너무 많이 읽어서 생긴 에피소드들이며, 지금제가 사용하는 한글까지\n\n정말 우리나라에서 없어서는 안될 대단하신 분이라 할 수 있지요\n그런분을 기리기 위해 만든 동상^^\n\n서울에 한 가운데 이런 위대한 동상이 있어서 뿌듯합니다.\n우리나라의 중심이라고 해도 과언이아니다 어떤한국영상에도 나오는 이동상 한글을 만드신 위대하신분의동상 주변 관광명소도많이있다\n이순신장군, 세종대왕 동상은 한번씩 꼭 봐야죠 ㅎㅎ 외쿡인은 뭐 아니더라도 우리한테는 중요한 인물, 아이들한테도 한번씩 보여주시길 추천합니다. 지방계신분들은 서울 종로 나들이 추천해요\n아래 내려가면 더 많은 정보 얻을 수 있어요!\n아이들 데리고 가서 직접 보고 느끼면 참 좋을 것 같아요\n세종대왕은 전세계 누구에게나 자랑하고 싶은 최고의 역사적인물입니다.\n서울도심의 랜드마크이자 동상 그 자체만으로도 너무 멋져요\n광화문 광장에 가면 바로 볼 수 있는 세종대왕 동상이에요. 위엄있고 한번 들러 보고 가기 좋습니다.\n한국의 한글을 창시한 세종대왕\n지금 이렇게 한글을 쓰면서 감사한 마음이 또드네요 세종대왕 동상을 보면서 한글에대해 다시한번 되새겨보는것도 좋을듯해요\n광화문 광장에 있어요!!! 한글을 창제하신 세종대왕의 동상이죠~~ 온화한 표정을 짓고있어요!!!\n세종 대왕님의 역사를 생각 하면서, 우리의 말문을 트게 만드신 분이라 항상 이곳을 지날때 마다 먼저 이순신 장군님을 바라보고,\n그다음 뒤편에 세종 대왕님을 바라보면서 국사에 대한 많을 생각을 갖게 만드는 중요한 장소라 생각 한다.\n광화문의 랜드마크이자 서울의 랜드마크죠\n볼때마다 기분 좋아지는 동상입니다\n세종대왕님 만세 만만세\n세종대왕을 존경하고 그분의 업적을 모르는 바는 아니지만 구지 광화문 광장 한 가운데 이런 거대한 크기의 동상을 세워야만 했을까 싶은 대형 조각물.\n자타공인 대한민국 역사에 있어서 언제나 손에 꼽히는 성왕. 경복궁이나 교보문고등을 들를 예정이라면 한번쯤 가봐야 할 곳\n광화문 세종대왕 하면 누구나 알 정도로 랜드마크.\n뒤에는 경복궁이 보여서 멋이다. 서울놀러온 사람은 가보시길\n이순신 장군의 동상을 지나면 애민정신이 가득했던 조선 최고의 임금이 인자한 손짓으로 맞이해준다.\n광화문이 광장으로 바뀌게 된 후 자주 걷게 되는 곳인데 우리로서는 신기함이 덜하지만 외국인들은 반드시 사진기를 꺼내게 만드는 곳이다.\n너무나 업적이 많으신 우리나라의 세종대왕님. 경복궁 앞, 광화문 광장 한복판에 계시는 모습을 볼 때마다 뭔가 뭉클해요. 외국인들도 많이 찾는 관광명소가 되었던데, 저녁에 들러도 멋있답니다.\n많은 사진이 없당 ㅠㅠ\n아이와 가기도 좋고 친구들과 잠시 들려 보는것도 좋다\n훈미정음 탄생 안내도 이순신장군의 거북선 모델도\n다양하게 구경 체험 할수 있다\n서울 광화문에 있는 세종대왕의 동상으로 세종대왕이 발명한 한글, 측우기등등이 전시되어 있기도 하다.. 바로 앞에는 이순신 장군의 동상이 있다.\n생각보다 꽤 크고 위엄돋습니다. 전 종로구민이라 허구헌날 지나쳐서 별 감흥이 없긴 한데, 타지역 분이시나 외국인들에게는 굉장히 인상적일 거에요. 경복궁이나 종로구 일대 구경하러 왔다면 꼭한번 보고가시고, 날이 더우면 지하에 있는 '세종대왕 이야기' 전시장 한번 둘러보시며 땀 식히고 가시길.\n광화문광장에 이순신동상과\n함께 자리잡은 자랑스러운 세종대왕동상입니다 지하에는 한글체헌전시관도 있고 광장에 정말 멋있게 자리잡고 있습니다\n한국인의 말과 생각은 이 왕을 통해 비로소 정리되었다고 할 수 있다. 서울의 심장부에 조선 왕조를 상징하는 경복궁 앞, 시민 정신을 상징하는 광화문 한가운데 세종대왕상이 자리 잡았다는 것은 그만큼 대한민국 사람들이 세종대왕을 사랑하고 있다는 것을 보여주는 것이다. 한글을 창제한 세종대왕 상은 광화문을 지난다면 꼭 한 번 보고 갈 가치가 있다.\n서울을 내려보는 듯한 광화문 거리 중심에 위치하고 있습니다. 아래에는 작은 한글 박물관이 있어요. 교육상에도 좋을 것 같습니다\n꼭 세종대왕 동상 보신 후에는 밑에 박물관 구경하세요~ 한글 창제부터 이순신 장군의 배틀까지!! 놓치지 마세요\n한글창제라는 위업을 세우신 세종대왕의 동상이 광화문 광장의 심장부를 지키고 있다.\n가까이서 보면 생각보다 커서 아래쪽에 서서 사진 찍는 사람들이 많다.\n광화문앞에 있는 세종대왕 동상입니다. 세종대왕은 한국인들에게 존경받는 성왕 중 한분이십니다. 한국의 글인 한글을 만드셨습니다.\n한국의 자랑스러운 세종대왕,\n동상의 위치가 개인적으론 눈에 안띄는 곳이라 생각하지만\n아무튼 중요한 자랑스런 기념물\n이순신 동상과 함꼐 서울을 대표하는 동상으로 광화문 광장에 위치해 있다.\n광화문 쪽에서 보면 뒤로 보이니, 서울 쪽에서 광화문으로 걸어오면서 찍는 모습이 더 멋지게 나온다.\n낮에는 좀 덥고, 저녁 먹고 커피한잔 들고 가면 시원하게 바람 쐴 수 있어요. 도심 한가운데 차도 막 다니는데, 그 사이에 있어서 좀 더 색다른 느낌의 휴식을 취할 수 있어요\n세종대왕님이 어여쁜 백성들에게 한글창제를 선포하고\n널리 사용하라는 자태로 앉아 계시는 장소.\n세종문화회관과 이순신동상까지 뻗은 거리는 관광지로 손색이 없습니다.\n세종대왕이 만든 한글이 없었다면 우리 나라의 교육과 문화, 그리고 더 나가서 세계적 명성을 떨치고 있는 IT 산업이 과연 현재와 같이 빛을 발하고 있었슬까? 늘 되새겨 보며 세종대왕상 방문시 마다 마음속 깊이에서 우러나오는 경의를 표하게 됩니다.\n한글을 만드신 조선 제일의 군왕. 조선의 기틀을 만들고 600년간 이어갈 기반을 다졌다. 세종로 광장 한 복판에 위치하여 안 보고 가기도 어려운 곳.\n광화문 광장에 오면 세종대왕 동상만 딱 보고 가는 경우는 없죠. 주위에 갈 곳, 볼 곳이 많으니깐요. 한글창제에 대한 고마움을 생각해 보는 것도 좋습니다.\n광장이 잘 꾸며져 있어 사진찍기 좋은 곳,\n서울 사람이 ...

# %%
tokens_review=t.nouns(review)

# %%
tokens_review
# Out:
# ['조선',
#  '왕',
#  '세종',
#  '과학',
#  '발전',
#  '데',
#  '힘',
#  '그',
#  '창제',
#  '한글',
#  '역시',
#  '과학',
#  '성의',
#  '측면',
#  '매우',
#  '결과물',
#  '광화문',
#  '앞',
#  '세종로',
#  '노상',
#  '시민',
#  '광장',
#  '조성',
#  '설치',
#  '그',
#  '결과',
#  '기존',
#  '이순신',
#  '장군',
#  '입상',
#  '광장',
#  '상징물',
#  '자리',
#  '동상',
#  '세종대왕',
#  '좌상',
#  '구성',
#  '주위',
#  '그',
#  '과학',
#  '대한',
#  '관심',
#  '발명',
#  '모형',
#  '전시',
#  '곳',
#  '길',
#  '이름',
#  '그',
#  '것',
#  '곳',
#  '의미',
#  '부여',
#  '광화문',
#  '이순신',
#  '동상',
#  '가운데',
#  '설치',
#  '문과',
#  '조화',
#  '또한',
#  '점',
#  '야간',
#  '볼거리',
#  '곳',
#  '서울',
#  '광화문',
#  '광장',
#  '웅장',
#  '세종대왕',
#  '동상',
#  '보노',
#  '라면',
#  '시대',
#  '사람',
#  '무언가',
#  '마다',
#  '것',
#  '대왕',
#  '모습',
#  '숙연',
#  '광화문',
#  '행시',
#  '사진',
#  '곳',
#  '광화문',
#  '대로',
#  '중간',
#  '우뚝',
#  '찾기',
#  '외국인',
#  '세종대왕',
#  '동상',
#  '앞',
#  '사진',
#  '한국인',
#  '자부심',
#  '한글',
#  '발명',
#  '세종대왕',
#  '위엄',
#  '동상',
#  '정말',
#  '조명',
#  '우리말',
#  '우리',
#  '글',
#  '아마',
#  '지금',
#  '조사',
#  '조선시대',
#  '통틀어',
#  '가장',
#  '알',
#  '가장',
#  '임금',
#  '한글',
#  '하나',
#  '모든',
#  '방',
#  '가지',
#  '분',
#  '광화문',
#  '광장',
#  '주변',
#  '여러',
#  '궁',
#  '미술관',
#  '박물관',
#  '전',
#  '사진',
#  '장',
#  '것',
#  '서울',
#  '상징',
#  '중',
#  '하나',
#  '조선',
#  '군주',
#  '이자',
#  '국민',
#  '존경',
#  '위인',
#  '위로',
#  '분',
#  '집현전',
#  '학자',
#  '한글',
#  '사실',
#  '집현전',
#  '학자',
#  '한글',
#  '반대',
#  '군주',
#  '스스로',
#  '한글',
#  '창제',
#  '것',
#  '인물',
#  '세종대왕',
#  '사람',
#  '칭송',
#  '사실',
#  '놈',
#  '조선',
#  '노비',
#  '제도',
#  '세종대왕',
#  '이기',
#  '때문',
#  '역사',
#  '역사',
#  '보아',
#  '한글',
#  '놈',
#  '학자',
#  '또',
#  '한자',
#  '위해',
#  '한글',
#  '때',
#  '위인',
#  '전',
#  '때',
#  '생각',
#  '정말',
#  '세종대왕',
#  '정말',
#  '천재',
#  '때',
#  '책',
#  '에피소드',
#  '금제',
#  '사용',
#  '한글',
#  '정말',
#  '우리나라',
#  '분',
#  '수',
#  '분',
#  '리기',
#  '위해',
#  '동상',
#  '서울',
#  '가운데',
#  '동상',
#  '우리나라',
#  '중심',
#  '해도',
#  '과언',
#  '한국영',
#  '이동상',
#  '한글',
#  '신분',
#  '동상',
#  '주변',
#  '관광명소',
#  '이순신장군',
#  '세종대왕',
#  '동상',
#  '한번',
#  '꼭',
#  '외쿡인',
#  '뭐',
#  '우리',
#  '인물',
#  '아이',
#  '도',
#  '한번',
#  '추천',
#  '지방',
#  '신분',
#  '서울',
#  '종로',
#  '나들이',
#  '추천',
#  '아래',
#  '더',
#  '정보',
#  '수',
#  '아이',
#  '데리',
#  '직접',
#  '보고',
#  '것',
#  '세종대왕',
#  '전세계',
#  '누구',
#  '자랑',
#  '최고',
#  '역사',
#  '인물',
#  '도심',
#  '랜드마크',
#  '이자',
#  '동상',
#  '그',
#  '자체',
#  '광화문',
#  '광장',
#  '가면',
#  '바로',
#  '볼',
#  '수',
#  '세종대왕',
#  '동상',
#  '위엄',
#  '한번',
#  '보고',
#  '가기',
#  '한국',
#  '한글',
#  '창',
#  '시한',
#  '세종대왕',
#  '지금',
#  '한글',
#  '마음',
#  '또드네',
#  '세종대왕',
#  '동상',
#  '한글',
#  '대해',
#  '다시',
#  '한번',
#  '해',
#  '광화문',
#  '광장',
#  '한글',
#  '창제',
#  '세종대왕',
#  '상이',
#  '표정',
#  '세종',
#  '대왕',
#  '역사',
#  '생각',
#  '우리',
#  '말문',
#  '트',
#  '분',
#  '항상',
#  '곳',
#  '때',
#  '마다',
#  '먼저',
#  '이순신',
#  '장군',
#  '그다음',
#  '뒤편',
#  '세종',
#  '대왕',
#  '국사',
#  '대한',
#  '생각',
#  '장소라',
#  '생각',
#  '광화문',
#  '랜드마크',
#  '이자',
#  '서울',
#  '랜드마크',
#  '볼때',
#  '기분',
#  '동상',
#  '세종대왕',
#  '만세',
#  '만세',
#  '세종대왕',
#  '존경',
#  '분',
#  '업적',
#  '바',
#  '구지',
#  '광화문',
#  '광장',
#  '가운데',
#  '크기',
#  '동상',
#  '대형',
#  '조각',
#  '물',
#  '자타공인',
#  '대한민국',
#  '역사',
#  '손',
#  '성왕',
#  '경복궁',
#  '교보',
#  '고등',
#  '예정',
#  '라면',
#  '한번',
#  '곳',
#  '광화문',
#  '세종대왕',
#  '누구',
#  '알',
#  '정도',
#  '랜드마크',
#  '뒤',
#  '경복궁',
#  '보',
#  '멋',
#  '서울',
#  '온',
#  '사람',
#  '이순신',
#  '장군',
#  '동상',
#  '애민',
#  '정신',
#  '조선',
#  '최고',
#  '임금',
#  '손짓',
#  '맞이',
#  '광화문',
#  '광장',
#  '후',
#  '자주',
#  '곳',
#  '우리',
#  '로서',
#  '외국인',
#  '반드시',
#  '사진기',
#  '곳',
#  '업적',
#  '우리나라',
#  '세종대왕',
#  '경복궁',
#  '앞',
#  '광화문',
#  '광장',
#  '복판',
#  '모습',
#  '볼',
#  '때',
#  '뭔가',
#  '외국인',
#  '관광명소',
#  '저녁',
#  '사진',
#  '아이',
#  '가기',
#  '친구',
#  '잠시',
#  '훈',
#  '미정',
#  '음',
#  '탄생',
#  '안내',
#  '이순신장군',
#  '거북선',
#  '모델',
#  '구경',
#  '체험',
#  '서울',
#  '광화문',
#  '세종대왕',
#  '동상',
#  '세종대왕',
#  '발명',
#  '한글',
#  '측우기',
#  '등등',
#  '전시',
#  '바로',
#  '앞',
#  '이순신',
#  '장군',
#  '동상',
#  '생각',
#  '꽤',
#  '위엄',
#  '전',
#  '종로',
#  '구민',
#  '허구',
#  '날',
#  '별',
#  '감흥',
#  '지역',
#  '외국인',
#  '인상',
#  '일',
#  '거',
#  '경복궁',
#  '종로구',
#  '일대',
#  '구경',
#  '꼭',
#  '한번',
#  '날',
#  '지하',
#  '세종대왕',
#  '이야기',
#  '전시장',
#  '한번',
#  '땀',
#  '광화문',
#  '광장',
#  '이순신',
#  '동상',
#  '자리',
#  '세종대왕',
#  '동상',
#  '지하',
#  '한글',
#  '체',
#  '전시관',
#  '광장',
#  '정말',
#  '자리',
#  '잡고',
#  '한국인',
#  '말',
#  '생각',
#  '이',
#  '왕',
#  '통해',
#  '비로소',
#  '정리',
#  '수',
#  '서울',
#  '심장',
#  '부',
#  '조선',
#  '왕조',
#  '상징',
#  '경복궁',
#  '앞',
#  '시민',
#  '정신',
#  '상징',
#  '광화문',
#  '한가운데',
#  '세종대왕',
#  '상이',
#  '자리',
#  '것',
#  '대한민국',
#  '사람',
#  '세종대왕',
#  '사랑',
#  '것',
#  '것',
#  '한글',
#  '창제',
#  '세종대왕',
#  '상',
#  '광화문',
#  '꼭',
#  '번',
#  '보고',
#  '가치',
#  '서울',
#  '듯',
#  '광화문',
#  '거리',
#  '중심',
#  '위치',
#  '아래',
#  '한글',
#  '박물관',
#  '교육',
#  '것',
#  '꼭',
#  '세종대왕',
#  '동상',
#  '보신',
#  '후',
#  '밑',
#  '박물관',
#  '구경',
#  '한글',
#  '창제',
#  '이순신',
#  '장군',
#  '배틀',
#  '한글',
#  '창제',
#  '위업',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '광장',
#  '심장',
#  '가까이',
#  '생각',
#  '커서',
#  '아래쪽',
#  '서서',
#  '사진',
#  '사람',
#  '광화문',
#  '앞',
#  '세종대왕',
#  '동상',
#  '세종대왕',
#  '한국인',
#  '존경',
#  '성왕',
#  '중',
#  '분',
#  '니',
#  '한국',
#  '글',
#  '한글',
#  '한국',
#  '세종대왕',
#  '동상',
#  '위치',
#  '개인',
#  '눈',
#  '곳',
#  '생각',
#  '기념물',
#  '이순신',
#  '동상',
#  '서울',
#  '대표',
#  '동상',
#  '광화문',
#  '광장',
#  '위치',
#  '광화문',
#  '쪽',
#  '뒤',
#  '서울',
#  '쪽',
#  '광화문',
#  '모습',
#  '더',
#  '낮',
#  '좀',
#  '저녁',
#  '커피한잔',
#  '가면',
#  '바람',
#  '수',
#  '도심',
#  '한가운데',
#  '차도',
#  '막',
#  '그',
#  '사이',
#  '좀',
#  '더',
#  '느낌',
#  '휴식',
#  '취할',
#  '수',
#  '세종대왕',
#  '백성',
#  '한글',
#  '창제',
#  '선포',
#  '널리',
#  '사용',
#  '자태',
#  '장소',
#  '세종',
#  '문화',
#  '회관',
#  '이순신',
#  '동상',
#  '거리',
#  '관광지',
#  '손색',
#  '세종대왕',
#  '한글',
#  '우리',
#  '나라',
#  '교육',
#  '문화',
#  '더',
#  '세계',
#  '명성',
#  '산업',
#  '과연',
#  '현재',
#  '빛',
#  '발',
#  '있었슬까',
#  '늘',
#  '세종대왕',
#  '방문',
#  '시',
#  '마다',
#  '마음속',
#  '깊이',
#  '러',
#  '경의',
#  '표',
#  '한글',
#  '조선',
#  '제일',
#  '군왕',
#  '조선',
#  '기틀',
#  '기반',
#  '세종로',
#  '광장',
#  '복판',
#  '위치',
#  '안',
#  '보고',
#  '가기',
#  '곳',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '동상',
#  '보고',
#  '경우',
#  '주위',
#  '곳',
#  '볼',
#  '곳',
#  '요',
#  '한글',
#  '창제',
#  '대한',
#  '고마움',
#  '생각',
#  '것',
#  '광장',
#  '사진',
#  '찍기',
#  '곳',
#  '서울',
#  '사람',
#  '라면',
#  '그냥',
#  '서울',
#  '여행',
#  '온',
#  '사람',
#  '여름',
#  '분수',
#  '광화문',
#  '사진',
#  '찍기',
#  '이순신',
#  '장군',
#  '동상',
#  '뒤',
#  '세종대왕',
#  '동상',
#  '측우기',
#  '사진',
#  '찍기',
#  '곳',
#  '한글',
#  '대한',
#  '관심',
#  '동상',
#  '밑',
#  '지하',
#  '한글',
#  '박물관',
#  '무료',
#  '관람',
#  '광화문',
#  '이순신',
#  '동상',
#  '편',
#  '세종대왕',
#  '상이',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '것',
#  '근처',
#  '세종',
#  '문화',
#  '회관',
#  '경복궁',
#  '광화문',
#  '교보',
#  '문고',
#  '등',
#  '수',
#  '광화문',
#  '사진',
#  '찍기',
#  '곳',
#  '여름',
#  '옆',
#  '분수',
#  '틀',
#  '쉬기',
#  '양옆',
#  '지나',
#  '별로',
#  '보통',
#  '중국',
#  '달라',
#  '알',
#  '계',
#  '신분',
#  '당시',
#  '중국',
#  '명나라',
#  '중화사상',
#  '중국',
#  '지금',
#  '중국',
#  '일',
#  '수도',
#  '언어',
#  '관련',
#  '교수',
#  '지역별',
#  '다른',
#  '말',
#  '통일',
#  '학설',
#  '분',
#  '광화문',
#  '광장',
#  '종로',
#  '쪽',
#  '충무공',
#  '동상',
#  '경복궁',
#  '쪽',
#  '세종대왕',
#  '동상',
#  '처음',
#  '좀',
#  '뜬금',
#  '동상',
#  '생각',
#  '시간',
#  '나름',
#  '편의',
#  '경복궁',
#  '생각',
#  '광화문',
#  '광장',
#  '눈',
#  '곳',
#  '관광객',
#  '사진',
#  '포인트',
#  '과거',
#  '광화문',
#  '이순신',
#  '장군',
#  '동상',
#  '한글',
#  '조선',
#  '최고',
#  '왕',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '광장',
#  '문무',
#  '겸비',
#  '더',
#  '것',
#  '중국인',
#  '관광객',
#  '단체',
#  '사진',
#  '찍',
#  '만큼',
#  '광화문',
#  '광장',
#  '포인트',
#  '세종대왕',
#  '동상',
#  '말',
#  '그대로',
#  '좀',
#  '어거지',
#  '조형',
#  '물이',
#  '광화문',
#  '그',
#  '대로',
#  '한가운데',
#  '광장',
#  '충무공',
#  '이순신',
#  '장군',
#  '동상',
#  '짝',
#  '뒤',
#  '세종',
#  '대왕',
#  '것',
#  '평소',
#  '곳',
#  '대한민국',
#  '이슈',
#  '발생',
#  '또',
#  '곳',
#  '다른',
#  '의미',
#  '군중',
#  '집단',
#  '것',
#  '외국인',
#  '우리나라',
#  '사진',
#  '스팟',
#  '중',
#  '하나',
#  '듯해',
#  '항상',
#  '사람',
#  '북적',
#  '곳',
#  '이순신',
#  '동상',
#  '랜드마크',
#  '그냥',
#  '세종대왕',
#  '동상',
#  '이구',
#  '뒤',
#  '훈민정음',
#  '창제',
#  '관련',
#  '전시',
#  '실',
#  '광화문',
#  '역',
#  '여기',
#  '한번',
#  '보시',
#  '바로',
#  '경복궁',
#  '가시',
#  '늘',
#  '관광객',
#  '외국인',
#  '관광객',
#  '기념',
#  '사진',
#  '찍기',
#  '위해',
#  '꼭',
#  '곳',
#  '밤',
#  '야경',
#  '무척',
#  '근처',
#  '엔젤리너스',
#  '카페',
#  '커피',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '동상',
#  '무척',
#  '한글',
#  '창시자',
#  '의미',
#  '조선',
#  '왕',
#  '앞',
#  '충무공',
#  '동상',
#  '정도',
#  '예술',
#  '가치나',
#  '그',
#  '위엄',
#  '수',
#  '그',
#  '뒤',
#  '이',
#  '세종대왕',
#  '동상',
#  '동상',
#  '자체',
#  '예술',
#  '가치',
#  '평가',
#  '쌩뚱맞',
#  '위치',
#  '것임',
#  '서울',
#  '중심',
#  '수',
#  '광화문',
#  '광장',
#  '가운데',
#  '위치',
#  '그',
#  '근처',
#  '자연',
#  '볼',
#  '수',
#  '서울',
#  '명물',
#  '역사상',
#  '가장',
#  '수',
#  '왕',
#  '동상',
#  '만큼',
#  '아이',
#  '외국',
#  '친구',
#  '꼭',
#  '소개',
#  '함',
#  '곳',
#  '보지',
#  '서울',
#  '말',
#  '수',
#  '정도',
#  '서울',
#  '대표',
#  '거리',
#  '각종',
#  '집회',
#  '문화',
#  '행사',
#  '곳',
#  '근처',
#  '교보',
#  '문고',
#  '세종',
#  '문화',
#  '회관',
#  '지하',
#  '갤러리',
#  '등',
#  '수',
#  '한글',
#  ...]

# %%
stopwords = [str, "또한", "방문", "여행","시간", "타고", "정말", "가장", "항상", "도착", "다른", "매우", "경우", "우리", "이용" ,"모든", "때문", "장소", "지역", "그것"]

# %%
tokens_review[1]
# Out:
# '왕'

# %%
tokens_review2=[w for w in tokens_review if w not in stopwords and len(w)>1]

# %%
tokens_review2
# Out:
# ['조선',
#  '세종',
#  '과학',
#  '발전',
#  '창제',
#  '한글',
#  '역시',
#  '과학',
#  '성의',
#  '측면',
#  '결과물',
#  '광화문',
#  '세종로',
#  '노상',
#  '시민',
#  '광장',
#  '조성',
#  '설치',
#  '결과',
#  '기존',
#  '이순신',
#  '장군',
#  '입상',
#  '광장',
#  '상징물',
#  '자리',
#  '동상',
#  '세종대왕',
#  '좌상',
#  '구성',
#  '주위',
#  '과학',
#  '대한',
#  '관심',
#  '발명',
#  '모형',
#  '전시',
#  '이름',
#  '의미',
#  '부여',
#  '광화문',
#  '이순신',
#  '동상',
#  '가운데',
#  '설치',
#  '문과',
#  '조화',
#  '야간',
#  '볼거리',
#  '서울',
#  '광화문',
#  '광장',
#  '웅장',
#  '세종대왕',
#  '동상',
#  '보노',
#  '라면',
#  '시대',
#  '사람',
#  '무언가',
#  '마다',
#  '대왕',
#  '모습',
#  '숙연',
#  '광화문',
#  '행시',
#  '사진',
#  '광화문',
#  '대로',
#  '중간',
#  '우뚝',
#  '찾기',
#  '외국인',
#  '세종대왕',
#  '동상',
#  '사진',
#  '한국인',
#  '자부심',
#  '한글',
#  '발명',
#  '세종대왕',
#  '위엄',
#  '동상',
#  '조명',
#  '우리말',
#  '아마',
#  '지금',
#  '조사',
#  '조선시대',
#  '통틀어',
#  '임금',
#  '한글',
#  '하나',
#  '가지',
#  '광화문',
#  '광장',
#  '주변',
#  '여러',
#  '미술관',
#  '박물관',
#  '사진',
#  '서울',
#  '상징',
#  '하나',
#  '조선',
#  '군주',
#  '이자',
#  '국민',
#  '존경',
#  '위인',
#  '위로',
#  '집현전',
#  '학자',
#  '한글',
#  '사실',
#  '집현전',
#  '학자',
#  '한글',
#  '반대',
#  '군주',
#  '스스로',
#  '한글',
#  '창제',
#  '인물',
#  '세종대왕',
#  '사람',
#  '칭송',
#  '사실',
#  '조선',
#  '노비',
#  '제도',
#  '세종대왕',
#  '이기',
#  '역사',
#  '역사',
#  '보아',
#  '한글',
#  '학자',
#  '한자',
#  '위해',
#  '한글',
#  '위인',
#  '생각',
#  '세종대왕',
#  '천재',
#  '에피소드',
#  '금제',
#  '사용',
#  '한글',
#  '우리나라',
#  '리기',
#  '위해',
#  '동상',
#  '서울',
#  '가운데',
#  '동상',
#  '우리나라',
#  '중심',
#  '해도',
#  '과언',
#  '한국영',
#  '이동상',
#  '한글',
#  '신분',
#  '동상',
#  '주변',
#  '관광명소',
#  '이순신장군',
#  '세종대왕',
#  '동상',
#  '한번',
#  '외쿡인',
#  '인물',
#  '아이',
#  '한번',
#  '추천',
#  '지방',
#  '신분',
#  '서울',
#  '종로',
#  '나들이',
#  '추천',
#  '아래',
#  '정보',
#  '아이',
#  '데리',
#  '직접',
#  '보고',
#  '세종대왕',
#  '전세계',
#  '누구',
#  '자랑',
#  '최고',
#  '역사',
#  '인물',
#  '도심',
#  '랜드마크',
#  '이자',
#  '동상',
#  '자체',
#  '광화문',
#  '광장',
#  '가면',
#  '바로',
#  '세종대왕',
#  '동상',
#  '위엄',
#  '한번',
#  '보고',
#  '가기',
#  '한국',
#  '한글',
#  '시한',
#  '세종대왕',
#  '지금',
#  '한글',
#  '마음',
#  '또드네',
#  '세종대왕',
#  '동상',
#  '한글',
#  '대해',
#  '다시',
#  '한번',
#  '광화문',
#  '광장',
#  '한글',
#  '창제',
#  '세종대왕',
#  '상이',
#  '표정',
#  '세종',
#  '대왕',
#  '역사',
#  '생각',
#  '말문',
#  '마다',
#  '먼저',
#  '이순신',
#  '장군',
#  '그다음',
#  '뒤편',
#  '세종',
#  '대왕',
#  '국사',
#  '대한',
#  '생각',
#  '장소라',
#  '생각',
#  '광화문',
#  '랜드마크',
#  '이자',
#  '서울',
#  '랜드마크',
#  '볼때',
#  '기분',
#  '동상',
#  '세종대왕',
#  '만세',
#  '만세',
#  '세종대왕',
#  '존경',
#  '업적',
#  '구지',
#  '광화문',
#  '광장',
#  '가운데',
#  '크기',
#  '동상',
#  '대형',
#  '조각',
#  '자타공인',
#  '대한민국',
#  '역사',
#  '성왕',
#  '경복궁',
#  '교보',
#  '고등',
#  '예정',
#  '라면',
#  '한번',
#  '광화문',
#  '세종대왕',
#  '누구',
#  '정도',
#  '랜드마크',
#  '경복궁',
#  '서울',
#  '사람',
#  '이순신',
#  '장군',
#  '동상',
#  '애민',
#  '정신',
#  '조선',
#  '최고',
#  '임금',
#  '손짓',
#  '맞이',
#  '광화문',
#  '광장',
#  '자주',
#  '로서',
#  '외국인',
#  '반드시',
#  '사진기',
#  '업적',
#  '우리나라',
#  '세종대왕',
#  '경복궁',
#  '광화문',
#  '광장',
#  '복판',
#  '모습',
#  '뭔가',
#  '외국인',
#  '관광명소',
#  '저녁',
#  '사진',
#  '아이',
#  '가기',
#  '친구',
#  '잠시',
#  '미정',
#  '탄생',
#  '안내',
#  '이순신장군',
#  '거북선',
#  '모델',
#  '구경',
#  '체험',
#  '서울',
#  '광화문',
#  '세종대왕',
#  '동상',
#  '세종대왕',
#  '발명',
#  '한글',
#  '측우기',
#  '등등',
#  '전시',
#  '바로',
#  '이순신',
#  '장군',
#  '동상',
#  '생각',
#  '위엄',
#  '종로',
#  '구민',
#  '허구',
#  '감흥',
#  '외국인',
#  '인상',
#  '경복궁',
#  '종로구',
#  '일대',
#  '구경',
#  '한번',
#  '지하',
#  '세종대왕',
#  '이야기',
#  '전시장',
#  '한번',
#  '광화문',
#  '광장',
#  '이순신',
#  '동상',
#  '자리',
#  '세종대왕',
#  '동상',
#  '지하',
#  '한글',
#  '전시관',
#  '광장',
#  '자리',
#  '잡고',
#  '한국인',
#  '생각',
#  '통해',
#  '비로소',
#  '정리',
#  '서울',
#  '심장',
#  '조선',
#  '왕조',
#  '상징',
#  '경복궁',
#  '시민',
#  '정신',
#  '상징',
#  '광화문',
#  '한가운데',
#  '세종대왕',
#  '상이',
#  '자리',
#  '대한민국',
#  '사람',
#  '세종대왕',
#  '사랑',
#  '한글',
#  '창제',
#  '세종대왕',
#  '광화문',
#  '보고',
#  '가치',
#  '서울',
#  '광화문',
#  '거리',
#  '중심',
#  '위치',
#  '아래',
#  '한글',
#  '박물관',
#  '교육',
#  '세종대왕',
#  '동상',
#  '보신',
#  '박물관',
#  '구경',
#  '한글',
#  '창제',
#  '이순신',
#  '장군',
#  '배틀',
#  '한글',
#  '창제',
#  '위업',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '광장',
#  '심장',
#  '가까이',
#  '생각',
#  '커서',
#  '아래쪽',
#  '서서',
#  '사진',
#  '사람',
#  '광화문',
#  '세종대왕',
#  '동상',
#  '세종대왕',
#  '한국인',
#  '존경',
#  '성왕',
#  '한국',
#  '한글',
#  '한국',
#  '세종대왕',
#  '동상',
#  '위치',
#  '개인',
#  '생각',
#  '기념물',
#  '이순신',
#  '동상',
#  '서울',
#  '대표',
#  '동상',
#  '광화문',
#  '광장',
#  '위치',
#  '광화문',
#  '서울',
#  '광화문',
#  '모습',
#  '저녁',
#  '커피한잔',
#  '가면',
#  '바람',
#  '도심',
#  '한가운데',
#  '차도',
#  '사이',
#  '느낌',
#  '휴식',
#  '취할',
#  '세종대왕',
#  '백성',
#  '한글',
#  '창제',
#  '선포',
#  '널리',
#  '사용',
#  '자태',
#  '세종',
#  '문화',
#  '회관',
#  '이순신',
#  '동상',
#  '거리',
#  '관광지',
#  '손색',
#  '세종대왕',
#  '한글',
#  '나라',
#  '교육',
#  '문화',
#  '세계',
#  '명성',
#  '산업',
#  '과연',
#  '현재',
#  '있었슬까',
#  '세종대왕',
#  '마다',
#  '마음속',
#  '깊이',
#  '경의',
#  '한글',
#  '조선',
#  '제일',
#  '군왕',
#  '조선',
#  '기틀',
#  '기반',
#  '세종로',
#  '광장',
#  '복판',
#  '위치',
#  '보고',
#  '가기',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '동상',
#  '보고',
#  '주위',
#  '한글',
#  '창제',
#  '대한',
#  '고마움',
#  '생각',
#  '광장',
#  '사진',
#  '찍기',
#  '서울',
#  '사람',
#  '라면',
#  '그냥',
#  '서울',
#  '사람',
#  '여름',
#  '분수',
#  '광화문',
#  '사진',
#  '찍기',
#  '이순신',
#  '장군',
#  '동상',
#  '세종대왕',
#  '동상',
#  '측우기',
#  '사진',
#  '찍기',
#  '한글',
#  '대한',
#  '관심',
#  '동상',
#  '지하',
#  '한글',
#  '박물관',
#  '무료',
#  '관람',
#  '광화문',
#  '이순신',
#  '동상',
#  '세종대왕',
#  '상이',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '근처',
#  '세종',
#  '문화',
#  '회관',
#  '경복궁',
#  '광화문',
#  '교보',
#  '문고',
#  '광화문',
#  '사진',
#  '찍기',
#  '여름',
#  '분수',
#  '쉬기',
#  '양옆',
#  '지나',
#  '별로',
#  '보통',
#  '중국',
#  '달라',
#  '신분',
#  '당시',
#  '중국',
#  '명나라',
#  '중화사상',
#  '중국',
#  '지금',
#  '중국',
#  '수도',
#  '언어',
#  '관련',
#  '교수',
#  '지역별',
#  '통일',
#  '학설',
#  '광화문',
#  '광장',
#  '종로',
#  '충무공',
#  '동상',
#  '경복궁',
#  '세종대왕',
#  '동상',
#  '처음',
#  '뜬금',
#  '동상',
#  '생각',
#  '나름',
#  '편의',
#  '경복궁',
#  '생각',
#  '광화문',
#  '광장',
#  '관광객',
#  '사진',
#  '포인트',
#  '과거',
#  '광화문',
#  '이순신',
#  '장군',
#  '동상',
#  '한글',
#  '조선',
#  '최고',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '광장',
#  '문무',
#  '겸비',
#  '중국인',
#  '관광객',
#  '단체',
#  '사진',
#  '만큼',
#  '광화문',
#  '광장',
#  '포인트',
#  '세종대왕',
#  '동상',
#  '그대로',
#  '어거지',
#  '조형',
#  '물이',
#  '광화문',
#  '대로',
#  '한가운데',
#  '광장',
#  '충무공',
#  '이순신',
#  '장군',
#  '동상',
#  '세종',
#  '대왕',
#  '평소',
#  '대한민국',
#  '이슈',
#  '발생',
#  '의미',
#  '군중',
#  '집단',
#  '외국인',
#  '우리나라',
#  '사진',
#  '스팟',
#  '하나',
#  '듯해',
#  '사람',
#  '북적',
#  '이순신',
#  '동상',
#  '랜드마크',
#  '그냥',
#  '세종대왕',
#  '동상',
#  '이구',
#  '훈민정음',
#  '창제',
#  '관련',
#  '전시',
#  '광화문',
#  '여기',
#  '한번',
#  '보시',
#  '바로',
#  '경복궁',
#  '가시',
#  '관광객',
#  '외국인',
#  '관광객',
#  '기념',
#  '사진',
#  '찍기',
#  '위해',
#  '야경',
#  '무척',
#  '근처',
#  '엔젤리너스',
#  '카페',
#  '커피',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '동상',
#  '무척',
#  '한글',
#  '창시자',
#  '의미',
#  '조선',
#  '충무공',
#  '동상',
#  '정도',
#  '예술',
#  '가치나',
#  '위엄',
#  '세종대왕',
#  '동상',
#  '동상',
#  '자체',
#  '예술',
#  '가치',
#  '평가',
#  '쌩뚱맞',
#  '위치',
#  '것임',
#  '서울',
#  '중심',
#  '광화문',
#  '광장',
#  '가운데',
#  '위치',
#  '근처',
#  '자연',
#  '서울',
#  '명물',
#  '역사상',
#  '동상',
#  '만큼',
#  '아이',
#  '외국',
#  '친구',
#  '소개',
#  '보지',
#  '서울',
#  '정도',
#  '서울',
#  '대표',
#  '거리',
#  '각종',
#  '집회',
#  '문화',
#  '행사',
#  '근처',
#  '교보',
#  '문고',
#  '세종',
#  '문화',
#  '회관',
#  '지하',
#  '갤러리',
#  '한글',
#  '창제',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '광장',
#  '한가운데',
#  '외국인',
#  '관광객',
#  '아주',
#  '자랑',
#  '생각',
#  '세종대왕',
#  '동상',
#  '근처',
#  '근처',
#  '가시',
#  '지하',
#  '길이',
#  '한글',
#  '박물관',
#  '전시',
#  '아이',
#  '한글',
#  '창제',
#  '대해',
#  '기회',
#  '세종대왕',
#  '나랏말씀',
#  '듕국',
#  '달라',
#  '서울',
#  '랜드마크',
#  '세종대왕',
#  '동상',
#  '세종',
#  '박물관',
#  '충무',
#  '박물관',
#  '예전',
#  '덕수궁',
#  '자주',
#  '주말',
#  '아이',
#  '교육',
#  '광화문',
#  '광장',
#  '가운데',
#  '세종대왕',
#  '동상',
#  '뒷쪽',
#  '통해',
#  '지하',
#  '기념관',
#  '볼거리',
#  '복판',
#  '가기',
#  '아이',
#  '학습',
#  '효과',
#  '참조',
#  '근처',
#  '교보',
#  '문고',
#  '경복궁',
#  '세종대왕',
#  '한국',
#  '존경',
#  '왕중',
#  '동상',
#  '광화문',
#  '거리',
#  '공간',
#  '존재',
#  '약간',
#  '광화문',
#  '광장',
#  '상징',
#  '손색',
#  '내부',
#  '여러가지',
#  '전시',
#  '이순신',
#  '장군',
#  '동상',
#  '구경',
#  '곳임',
#  '동상',
#  '아래',
#  '공간',
#  '저녁',
#  '세종대왕',
#  '업적',
#  '영상',
#  '물이',
#  '자료',
#  '존경',
#  '세종대왕',
#  '동상',
#  '광화문',
#  '서울',
#  '무게',
#  '유지',
#  '종로',
#  '광화문',
#  '볼거리',
#  '세종대왕',
#  '동상',
#  '대표',
#  '동상',
#  '일지',
#  '세종대왕',
#  '생각',
#  '의미',
#  '동상',
#  '한글날',
#  '맞이',
#  '행사',
#  '가족',
#  '해외',
#  '한국',
#  '사람',
#  '아이',
#  '한국',
#  '가면',
#  '하나로',
#  '동상',
#  '잠깐',
#  '보고',
#  '주위',
#  '역사',
#  '명소',
#  '일석이조',
#  '효과',
#  '광화문',
#  '경복궁',
#  '외국인',
#  '한글',
#  '사람',
#  '세종대왕',
#  '사람',
#  '실제',
#  '주변',
#  '경관',
#  '편이',
#  '경복궁',
#  '세종로',
#  '조성',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '한글',
#  '창제',
#  '경복궁',
#  '즉위',
#  '승하',
#  '최초',
#  '임금',
#  '역사',
#  '사실',
#  '고려',
#  '정신',
#  '세종대왕',
#  '동상',
#  '건립',
#  '민족',
#  '자긍심',
#  '높이',
#  '민족',
#  '우수',
#  '세계',
#  '널리',
#  '위해',
#  '세종대왕',
#  '동상',
#  '제작',
#  '한글날',
#  '세종대왕',
#  '동상',
#  '지하',
#  '기념관',
#  '이순신장군',
#  '기념관',
#  '광화문역',
#  '바로',
#  '가까이',
#  '광화문',
#  '광장',
#  '세종대왕',
#  '상이',
#  '멀리',
#  '서도',
#  '존재',
#  '세종대왕',
#  '금색',
#  '주변',
#  '사진',
#  '사람',
#  '지하',
#  '무료',
#  '입장',
#  '세종대왕',
#  '전시관',
#  '세종로',
#  '중앙',
#  '금색',
#  '동상',
#  '멀리',
#  '바로',
#  '정도',
#  '가까이',
#  '동상',
#  '얼마나',
#  '사진',
#  '추천',
#  '경복궁',
#  '광화문',
#  '북한',
#  '산도',
#  '서울',
#  '다운',
#  '사진',
#  '드라마',
#  '기도',
#  '세종대왕',
#  '거리',
#  '두둥',
#  ...]

# %%
fd_review=FreqDist(tokens_review2)

# %%
wc = WordCloud(width=2000, height=1300, background_color="white", random_state=0, font_path=font_location)
plt.imshow(wc.generate_from_frequencies(fd_review))
plt.axis("off") # 축 제거
plt.show()

# %%
plt.savefig("reviews/img/"+str+".png")
