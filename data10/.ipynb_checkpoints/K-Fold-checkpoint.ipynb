# %%
## enumerate함수 : 열거하다
## 많은 양의 데이터인 list를 다룰 때 편리하게 쓸 수 있는 기능을 제공
## for~each, for
# for x in list: 리스트에 있는 것을 하나씩 꺼내서 처리하기가 아주 간단
#                index가 없어서 불편!
#                하나씩 꺼내서 출력, 연산하기는 용이
#                리스트에 입력은 안된다.!
#for i inrange(n): 리스트의 입력과 출력이 모두 됨
#                  인덱스로 리스트에 있는 값들을 접근해야하기 때문에
#                  코드가 복잡하게 보인다.

# %%
num_list=[100, 200, 300]

# %%
for x in num_list:
    print(x+100)
# Out:
# 200
# 300
# 400

# %%
for x in enumerate(num_list):
    print(x)
# Out:
# (0, 100)
# (1, 200)
# (2, 300)

# %%
for i,x in enumerate(num_list):
    print(i,':', x)
# Out:
# 0 : 100
# 1 : 200
# 2 : 300

# %%
for i,x in enumerate(num_list):
    num_list[i]=x+100

# %%
num_list
# Out:
# [200, 300, 400]

# %%
kfold=KFold(n_splits=5)

# %%
import warnings
warnings.filterwarnings(action='ignore')
# warnings.filterwarnings(action='default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.datasets import fetch_openml
import sklearn.datasets as data
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
titanic=pd.read_csv('titanic_train.csv')
titanic
# Out:
#      pclass  survived                                           name     sex  \
# 0         2         1              Mellinger, Miss. Madeleine Violet  female
# 1         2         1                              Wells, Miss. Joan  female
# 2         2         1                 Duran y More, Miss. Florentina  female
# 3         3         0                             Scanlan, Mr. James    male
# 4         3         1                   Bradley, Miss. Bridget Delia  female
# ..      ...       ...                                            ...     ...
# 893       3         0                             Davies, Mr. Joseph    male
# 894       3         0                            Lockyer, Mr. Edward    male
# 895       1         0                              Fortune, Mr. Mark    male
# 896       3         1                     Dorking, Mr. Edward Arthur    male
# 897       1         1  Clark, Mrs. Walter Miller (Virginia McDowell)  female
#
# ...

# %%
## 함수(drop처리)
## name, ticket, body, home.dest

# %%
## 함수(na처리)
## na처리
## age는 평균으로 채워주세요
## cabin N으로 채워주세요.
## emberked는 N으로 채워주세요.(fillna())
## na개수가 몇개인지 전체 카운트

# %%
def drop_cols():
    titanic.drop(['name', 'ticket', 'body', 'home.dest'], axis=1, inplace=True)

# %%
titanic[titanic['age'].isna()==True]
# Out:
#      pclass  survived                                 name     sex  age  \
# 3         3         0                   Scanlan, Mr. James    male  NaN
# 5         3         0                 Linehan, Mr. Michael    male  NaN
# 14        3         0                    Webber, Mr. James    male  NaN
# 19        3         0           Moore, Mr. Leonard Charles    male  NaN
# 20        3         1    Mockler, Miss. Helen Mary "Ellie"  female  NaN
# ..      ...       ...                                  ...     ...  ...
# 867       3         1            O'Driscoll, Miss. Bridget  female  NaN
# 868       3         0  van Billiard, Master. James William    male  NaN
# 870       3         0                      Flynn, Mr. John    male  NaN
# 873       3         0                Jardin, Mr. Jose Neto    male  NaN
# 894       3         0                  Lockyer, Mr. Edward    male  NaN
#
#      sibsp  parch              ticket     fare cabin embarked   body home.dest
# ...

# %%
titanic['age'][titanic['age'].isna()==True]=titanic['age'].mean()

# %%
titanic[titanic['age'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, body, home.dest]
# Index: []

# %%
def fill_Nan():
    titanic['age'].fillna(titanic['age'].mean(), inplace=True)
    titanic['cabin'].fillna('N', inplace=True)
    titanic['embarked'].fillna('N', inplace=True)

# %%
drop_cols()

# %%
fill_Nan()

# %%
titanic
# Out:
#      pclass  survived     sex        age  sibsp  parch      fare        cabin  \
# 0         2         1  female  13.000000      0      1   19.5000            N
# 1         2         1  female   4.000000      1      1   23.0000            N
# 2         2         1  female  30.000000      1      0   13.8583            N
# 3         3         0    male  30.196882      0      0    7.7250            N
# 4         3         1  female  22.000000      0      0    7.7250            N
# ..      ...       ...     ...        ...    ...    ...       ...          ...
# 893       3         0    male  17.000000      2      0    8.0500            N
# 894       3         0    male  30.196882      0      0    7.8792            N
# 895       1         0    male  64.000000      1      4  263.0000  C23 C25 C27
# 896       3         1    male  19.000000      0      0    8.0500            N
# 897       1         1  female  26.000000      1      0  136.7792          C89
#
#     embarked
# 0          S
# ...

# %%
## 라벨인코딩: sex, cabin, embarked

# %%
# titanic['cabin']=titanic['cabin'].str[:1]
# titanic['cabin'][:20]

# %%
def label_encoding():
    titanic['cabin']=titanic['cabin'].str[:1]
    le=LabelEncoder()
    features=['sex', 'cabin', 'embarked']
    for f in features:
        le.fit(titanic[f])
        print('라벨링할 목록 => ', le.classes_)
        titanic[f]=le.transform(titanic[f])

# %%
label_encoding()
# Out:
# 라벨링할 목록 =>  ['female' 'male']
# 라벨링할 목록 =>  ['A' 'B' 'C' 'D' 'E' 'F' 'G' 'N' 'T']
# 라벨링할 목록 =>  ['C' 'N' 'Q' 'S']

# %%
titanic.head()
# Out:
#    pclass  survived  sex        age  sibsp  parch     fare  cabin  embarked
# 0       2         1    0  13.000000      0      1  19.5000      7         3
# 1       2         1    0   4.000000      1      1  23.0000      7         3
# 2       2         1    0  30.000000      1      0  13.8583      7         0
# 3       3         0    1  30.196882      0      0   7.7250      7         2
# 4       3         1    0  22.000000      0      0   7.7250      7         2

# %%
## 전처리 담당 함수 만들기
def preprocessing():
    drop_cols()
    fill_Nan()
    label_encoding()

# %%
titanic=pd.read_csv('titanic_train.csv')
titanic.head()
# Out:
#    pclass  survived                               name     sex   age  sibsp  \
# 0       2         1  Mellinger, Miss. Madeleine Violet  female  13.0      0
# 1       2         1                  Wells, Miss. Joan  female   4.0      1
# 2       2         1     Duran y More, Miss. Florentina  female  30.0      1
# 3       3         0                 Scanlan, Mr. James    male   NaN      0
# 4       3         1       Bradley, Miss. Bridget Delia  female  22.0      0
#
#    parch         ticket     fare cabin embarked  body  \
# 0      1         250644  19.5000   NaN        S   NaN
# 1      1          29103  23.0000   NaN        S   NaN
# 2      0  SC/PARIS 2148  13.8583   NaN        C   NaN
# 3      0          36209   7.7250   NaN        Q   NaN
# 4      0         334914   7.7250   NaN        Q   NaN
#
#                                            home.dest
# 0                           England / Bennington, VT
# 1                               Cornwall / Akron, OH
# ...

# %%
# 데이터 전처리 호출
preprocessing()
# Out:
# 라벨링할 목록 =>  ['female' 'male']
# 라벨링할 목록 =>  ['A' 'B' 'C' 'D' 'E' 'F' 'G' 'N' 'T']
# 라벨링할 목록 =>  ['C' 'N' 'Q' 'S']

# %%
titanic.head()
# Out:
#    pclass  survived  sex        age  sibsp  parch     fare  cabin  embarked
# 0       2         1    0  13.000000      0      1  19.5000      7         3
# 1       2         1    0   4.000000      1      1  23.0000      7         3
# 2       2         1    0  30.000000      1      0  13.8583      7         0
# 3       3         0    1  30.196882      0      0   7.7250      7         2
# 4       3         1    0  22.000000      0      0   7.7250      7         2

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 9 columns):
# pclass      898 non-null int64
# survived    898 non-null int64
# sex         898 non-null int32
# age         898 non-null float64
# sibsp       898 non-null int64
# parch       898 non-null int64
# fare        898 non-null float64
# cabin       898 non-null int32
# embarked    898 non-null int32
# dtypes: float64(2), int32(3), int64(4)
# memory usage: 52.7 KB

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'cabin',
#        'embarked'],
#       dtype='object')

# %%
t_data=['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'cabin', 'embarked']

# %%
X_train, X_test, y_train, y_test=train_test_split(
    titanic[t_data],
    titanic['survived'],
    test_size=0.2,
    random_state=None
)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((718, 8), (718,), (180, 8), (180,))

# %%
dt_clf=DecisionTreeClassifier(random_state=11)
rf_clf=RandomForestClassifier(random_state=11)
svc_clf=SVC()

# %%
#train데이터 3가지 방법으로 훈련데이터 훈련시켜서 정확도 비교!

# %%
dt_clf.fit(X_train, y_train)
result=dt_clf.predict(X_test)
accuracy_score(result, y_test)
# Out:
# 0.7444444444444445

# %%
rf_clf.fit(X_train, y_train)
result=rf_clf.predict(X_test)
accuracy_score(result, y_test)
# Out:
# 0.7277777777777777

# %%
svc_clf.fit(X_train, y_train)
result=svc_clf.predict(X_test)
accuracy_score(result, y_test)
# Out:
# 0.6

# %%
clf_list=[dt_clf, rf_clf, svc_clf]
def comapre_clf():
    for one in clf_list:
        one.fit(X_train, y_train)
        result=one.predict(X_test)
        accuracy_score(result, y_test)

# %%
kfold=KFold(n_splits=5)

# %%
for i, (train_index, test_index) in enumerate(kfold.split(titanic[t_data])):
    print(i, '===========================================================================================')
    print('train_index>>', train_index)
    print('test_index>>', test_index)
# Out:
# 0 ===========================================================================================
# train_index>> [180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
#  324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 340 341
#  342 343 344 345 346 347 348 349 350 351 352 353 354 355 356 357 358 359
#  360 361 362 363 364 365 366 367 368 369 370 371 372 373 374 375 376 377
# ...

# %%
titanic[t_data]
# Out:
#      pclass  sex        age  sibsp  parch      fare  cabin  embarked
# 0         2    0  13.000000      0      1   19.5000      7         3
# 1         2    0   4.000000      1      1   23.0000      7         3
# 2         2    0  30.000000      1      0   13.8583      7         0
# 3         3    1  30.196882      0      0    7.7250      7         2
# 4         3    0  22.000000      0      0    7.7250      7         2
# ..      ...  ...        ...    ...    ...       ...    ...       ...
# 893       3    1  17.000000      2      0    8.0500      7         3
# 894       3    1  30.196882      0      0    7.8792      7         3
# 895       1    1  64.000000      1      4  263.0000      2         3
# 896       3    1  19.000000      0      0    8.0500      7         3
# 897       1    0  26.000000      1      0  136.7792      2         0
#
# [898 rows x 8 columns]

# %%
titanic[t_data].values[train_index]
# Out:
# array([[ 2.        ,  0.        , 13.        , ..., 19.5       ,
#          7.        ,  3.        ],
#        [ 2.        ,  0.        ,  4.        , ..., 23.        ,
#          7.        ,  3.        ],
#        [ 2.        ,  0.        , 30.        , ..., 13.8583    ,
#          7.        ,  0.        ],
#        ...,
#        [ 2.        ,  1.        , 44.        , ..., 13.        ,
#          7.        ,  3.        ],
#        [ 3.        ,  1.        , 21.        , ...,  6.4958    ,
#          7.        ,  3.        ],
#        [ 3.        ,  1.        , 30.19688187, ...,  7.8958    ,
#          7.        ,  3.        ]])

# %%
titanic[t_data].values[test_index]
# Out:
# array([[  3.        ,   1.        ,  27.        , ...,   7.8958    ,
#           7.        ,   3.        ],
#        [  3.        ,   1.        ,  18.5       , ...,   7.2292    ,
#           7.        ,   0.        ],
#        [  1.        ,   0.        ,  30.19688187, ...,  79.2       ,
#           7.        ,   0.        ],
#        ...,
#        [  1.        ,   1.        ,  64.        , ..., 263.        ,
#           2.        ,   3.        ],
#        [  3.        ,   1.        ,  19.        , ...,   8.05      ,
#           7.        ,   3.        ],
#        [  1.        ,   0.        ,  26.        , ..., 136.7792    ,
#           2.        ,   0.        ]])

# %%
j=0
dt_acc=[]
rf_acc=[]
svc_acc=[]
acc_list=[dt_acc, rf_acc, svc_acc]

for i, (train_index, test_index) in enumerate(kfold.split(titanic[t_data])):
    X_train2, X_test2=titanic[t_data].values[train_index], titanic[t_data].values[test_index]
    y_train2, y_test2=titanic['survived'].values[train_index], titanic['survived'].values[test_index]
    clf_name=['DT', 'RF', 'SVC']
    i=0
    
    for one in clf_list:
        one.fit(X_train2, y_train2)
        result=one.predict(X_test2)
        print(clf_name[i],':',accuracy_score(result, y_test2))    
        acc_list[i].append(accuracy_score(result, y_test2))
        i+=1
    print('------------fold '+str(j)+'------------')
    j+=1

print('DT 평균: {0}'.format(np.mean(dt_acc)))
print('RF 평균: {0}'.format(np.mean(rf_acc)))
print('SVC 평균: {0}'.format(np.mean(svc_acc)))
# Out:
# DT : 0.8055555555555556
# RF : 0.8333333333333334
# SVC : 0.6944444444444444
# ------------fold 0------------
# DT : 0.7166666666666667
# RF : 0.7388888888888889
# SVC : 0.6277777777777778
# ------------fold 1------------
# DT : 0.7388888888888889
# RF : 0.7666666666666667
# SVC : 0.6166666666666667
# ------------fold 2------------
# DT : 0.776536312849162
# RF : 0.7597765363128491
# SVC : 0.7262569832402235
# ------------fold 3------------
# DT : 0.8044692737430168
# RF : 0.8100558659217877
# SVC : 0.6033519553072626
# ------------fold 4------------
# DT 평균: 0.7684233395406579
# RF 평균: 0.7817442582247052
# SVC 평균: 0.653699565487275

# %%
## model list로 교차검증이 한꺼번에 되게 코드를 변경해보고
## model_list 중 평균값의 교차검증 결과 중 최대인 모델의 평균값을 구해보세요.
## 평균값이 제일 높은 모델을 선정해보세요!
## -------------------------------------------------------------
## 교차 검증 결과는
## 제일 정확도가 높은 모델은 랜덤포레스트이고, 정확도는 88입니다.
