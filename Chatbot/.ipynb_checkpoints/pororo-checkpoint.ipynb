# %%
# !pip install git+https://github.com/kakaobrain/pororo.git (이걸로 설치 x)
# Out:
# ...
#   Cloning https://github.com/kakaobrain/pororo.git to c:\users\hi\appdata\local\temp\pip-req-build-551t3irg
#   Resolved https://github.com/kakaobrain/pororo.git to commit 7d05a75e8062b00e6b65364b8ec6c52b6293ab07
# WARNING: Ignoring invalid distribution -llib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -erkzeug (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -llib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
# !pip install python-mecab-ko
# Out:
# ...
#   Running setup.py clean for python-mecab-ko
# Failed to build python-mecab-ko
# ...
#     Running setup.py install for python-mecab-ko: started
#     Running setup.py install for python-mecab-ko: finished with status 'error'
# WARNING: Ignoring invalid distribution -llib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -erkzeug (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -llib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
# !pip install pororo
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# WARNING: Ignoring invalid distribution -llib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\programdata\anaconda3\lib\site-packages)
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# ...
#   Installing build dependencies: started
# ...

# %%
from pororo import Pororo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12804\639728525.py in <module>
# ----> 1 from pororo import Pororo
#
# ModuleNotFoundError: No module named 'pororo'
